# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakera-M-Hanif/NLP_Projects/blob/main/NLP_WordNet_WordSimilarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NLP PRACTICAL-6 WordNet and Word Similarity**

# %% [markdown]
# The WordNet is a part of Python's Natural Language Toolkit. It is a large word database of English Nouns, Adjectives, Adverbs and Verbs. These are grouped into some set of cognitive synonyms, which are called synsets.
#
# This helps support NLP tasks such as sentiment analysis, automatic language translation, text similarity
#
#  synset():to look up words in WordNet. Synset instances are the groupings of synonymous words that express the same concept. Some of the words have only one Synset and some have several. wordnet
#
# A set of one or more synonyms that are interchangeable in some context without changing the truth value of the proposition in which they are embedded.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aim:To write a program to perform WordNet and check Word Similarity on English text.
# ---

# %% [markdown]
# #**WordNet**
#
#
# 1.   Synomyms
# 2.   Antonyms

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.corpus import wordnet

# %% [markdown]
# ###**To find synonym**

# %%
syns=wordnet.synsets("program")
print(syns)
#print(syns[0])
# Out:
# [Synset('plan.n.01'), Synset('program.n.02'), Synset('broadcast.n.02'), Synset('platform.n.02'), Synset('program.n.05'), Synset('course_of_study.n.01'), Synset('program.n.07'), Synset('program.n.08'), Synset('program.v.01'), Synset('program.v.02')]

# %%
print(syns[0].lemmas())
print(syns[0].lemmas()[0].name())
# Out:
# [Lemma('plan.n.01.plan'), Lemma('plan.n.01.program'), Lemma('plan.n.01.programme')]
# plan

# %%
# to find the definiton
print(syns[0].definition())
# Out:
# a series of steps to be carried out or goals to be accomplished

# %%
# to get an example 
print(syns[0].examples())
# Out:
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %% [markdown]
# ### **To find Antonyms**

# %%
from nltk.corpus import wordnet
antonyms = []
#defining the function to find Antonyms
def TofindAntonyms(x):
  for syn in wordnet.synsets(x):
    for lm in syn.lemmas():
        if lm.antonyms():
            antonyms.append(lm.antonyms()[0].name()) #adding into antonyms
  return antonyms
print(set(TofindAntonyms("bright")))
# Out:
# {'dull', 'dimmed'}

# %%
print(set(TofindAntonyms("inactive")))
# Out:
# {'operational', 'active', 'dull', 'dimmed'}

# %%
print(set(TofindAntonyms("good")))
# Out:
# {'evil', 'ill', 'operational', 'bad', 'badness', 'dimmed', 'evilness', 'dull', 'active'}

# %% [markdown]
# (or)

# %%
# to find synonyms and antonyms
synonyms=[]
antonyms=[]
for syn in wordnet.synsets("good"):
  for l in syn.lemmas():
    synonyms.append(l.name())
    if l.antonyms():
      antonyms.append(l.antonyms()[0].name())
print("Synonyms:",(set(synonyms)))
print("Antonyms:",(set(antonyms)))
# Out:
# Synonyms: {'beneficial', 'well', 'unspoiled', 'goodness', 'skillful', 'secure', 'in_effect', 'salutary', 'serious', 'honest', 'dear', 'near', 'ripe', 'good', 'full', 'thoroughly', 'expert', 'upright', 'practiced', 'right', 'just', 'trade_good', 'adept', 'estimable', 'honorable', 'skilful', 'soundly', 'proficient', 'safe', 'respectable', 'undecomposed', 'sound', 'in_force', 'unspoilt', 'dependable', 'commodity', 'effective'}
# Antonyms: {'evil', 'ill', 'bad', 'badness', 'evilness'}

# %% [markdown]
# #**WordSimilarity**

# %%
car=wordnet.synset('car.n.01')
automobile=wordnet.synset('automobile.n.01')

# %%
print("Similarity between car and automobile",car.path_similarity(automobile))
# Out:
# Similarity between car and automobile 1.0

# %% [markdown]
# (or)

# %% [markdown]
# ## **Wu-Palmer Similarity**

# %% [markdown]
# It calculates relatedness by considering the depths of the two synsets in the WordNet taxonomies, along with the depth of the LCS (Least Common Subsumer).The score can be 0 < score <= 1. The score can never be zero because the depth of the LCS is never zero (the depth of the root of taxonomy is one).
# It calculates the similarity based on how similar the word senses are and where the Synsets occur relative to each other in the hypernym tree

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# Example 1:

# %%
w1=wordnet.synset('run.v.01')# v here denotes the tag verb
w2= wordnet.synset('sprint.v.01')
print(w1.wup_similarity(w2))
# Out:
# 0.8571428571428571

# %% [markdown]
# Example 2:

# %%
jump=wn.synset('jump.v.01')
leap=wn.synset('leap.v.01')

# %%
print ("similarity between jump and leap ",jump.wup_similarity(leap))
# Out:
# similarity between jump and leap  1.0
